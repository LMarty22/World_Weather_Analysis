# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
weather_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"
url = weather_url + "appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = [ ]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | suao
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | riohacha
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | pochutla
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | hovd
# Processing Record 13 of Set 1 | mihail kogalniceanu
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | maragogi
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | kabo
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | nemuro
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 1 | vagay
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | prainha
# Processing Record 30 of Set 1 | juruti
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | jardim
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | mantua
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | verkhovazhye
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | ust-koksa
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | isangel
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | buchanan
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | vanderhoof
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | shaghat
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | aban
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | coxim
# Processing Record 22 of Set 2 | sagaing
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | havoysund
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | tanete
# Processing Record 27 of Set 2 | benguela
# Processing Record 28 of Set 2 | simao
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | nishihara
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | bundaberg
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | carballo
# Processing Record 40 of Set 2 | eisiskes
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | anito
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | lorengau
# Processing Record 47 of Set 2 | korem
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | nouadhibou
# Processing Record 50 of Set 2 | sao filipe
# Processing Record 1 of Set 3 | pecos
# Processing Record 2 of Set 3 | ust-ilimsk
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | kropotkin
# Processing Record 6 of Set 3 | college
# Processing Record 7 of Set 3 | duz
# City not found. Skipping...
# Processing Record 8 of Set 3 | vigrestad
# Processing Record 9 of Set 3 | sherbrooke
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | san cristobal
# Processing Record 12 of Set 3 | nuevo casas grandes
# Processing Record 13 of Set 3 | udachnyy
# Processing Record 14 of Set 3 | paamiut
# Processing Record 15 of Set 3 | aden
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | kemijarvi
# Processing Record 18 of Set 3 | mayumba
# Processing Record 19 of Set 3 | sisimiut
# Processing Record 20 of Set 3 | ujjain
# Processing Record 21 of Set 3 | mayo
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | verkhoyansk
# Processing Record 24 of Set 3 | sistranda
# Processing Record 25 of Set 3 | korla
# Processing Record 26 of Set 3 | marsh harbour
# Processing Record 27 of Set 3 | fairmont
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | la rioja
# Processing Record 30 of Set 3 | ascension
# Processing Record 31 of Set 3 | rafaela
# Processing Record 32 of Set 3 | gondanglegi
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | shingu
# Processing Record 35 of Set 3 | walvis bay
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | kimbe
# Processing Record 40 of Set 3 | redlands
# Processing Record 41 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 3 | gogrial
# Processing Record 43 of Set 3 | sorong
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | ulladulla
# Processing Record 46 of Set 3 | akdepe
# Processing Record 47 of Set 3 | kondopoga
# Processing Record 48 of Set 3 | apache junction
# Processing Record 49 of Set 3 | yongan
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | paita
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | marawi
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | zhob
# Processing Record 6 of Set 4 | merauke
# Processing Record 7 of Set 4 | santa maria del oro
# Processing Record 8 of Set 4 | hangu
# Processing Record 9 of Set 4 | tabou
# Processing Record 10 of Set 4 | isiro
# Processing Record 11 of Set 4 | sur
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | havre-saint-pierre
# Processing Record 14 of Set 4 | ponta delgada
# Processing Record 15 of Set 4 | akhtubinsk
# Processing Record 16 of Set 4 | rorvik
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | uvira
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | nabire
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | bathsheba
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | los llanos de aridane
# Processing Record 27 of Set 4 | oga
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | saint-joseph
# Processing Record 30 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 4 | pacific grove
# Processing Record 32 of Set 4 | norman wells
# Processing Record 33 of Set 4 | egvekinot
# Processing Record 34 of Set 4 | mgandu
# Processing Record 35 of Set 4 | chernyshevskiy
# Processing Record 36 of Set 4 | ketchikan
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | maldonado
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | saint austell
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | sterling
# Processing Record 43 of Set 4 | payyannur
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | debre sina
# Processing Record 46 of Set 4 | inirida
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | yar-sale
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | poyarkovo
# Processing Record 1 of Set 5 | morehead
# Processing Record 2 of Set 5 | mbandaka
# Processing Record 3 of Set 5 | darab
# Processing Record 4 of Set 5 | conde
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | ixtapa
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | natal
# Processing Record 9 of Set 5 | bella union
# Processing Record 10 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 5 | bac lieu
# Processing Record 12 of Set 5 | chimoio
# Processing Record 13 of Set 5 | vilyuysk
# Processing Record 14 of Set 5 | san fernando
# Processing Record 15 of Set 5 | kavieng
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | colares
# Processing Record 19 of Set 5 | nakusp
# Processing Record 20 of Set 5 | harper
# Processing Record 21 of Set 5 | bintulu
# Processing Record 22 of Set 5 | shizunai
# Processing Record 23 of Set 5 | santa isabel do rio negro
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 30 of Set 5 | takoradi
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | dalbandin
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | hay river
# Processing Record 35 of Set 5 | porto novo
# Processing Record 36 of Set 5 | kotido
# Processing Record 37 of Set 5 | mahmudabad
# Processing Record 38 of Set 5 | ust-kuyga
# Processing Record 39 of Set 5 | acarau
# Processing Record 40 of Set 5 | biak
# Processing Record 41 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 5 | tabuk
# Processing Record 43 of Set 5 | sheksna
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | beloha
# Processing Record 46 of Set 5 | mongo
# Processing Record 47 of Set 5 | beira
# Processing Record 48 of Set 5 | derzhavinsk
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | winslow
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 6 | vestmannaeyjar
# Processing Record 5 of Set 6 | belokurikha
# Processing Record 6 of Set 6 | coahuayana
# Processing Record 7 of Set 6 | nueva guinea
# Processing Record 8 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 9 of Set 6 | adrar
# Processing Record 10 of Set 6 | nanakuli
# Processing Record 11 of Set 6 | makakilo city
# Processing Record 12 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 6 | hereford
# Processing Record 14 of Set 6 | zhetybay
# City not found. Skipping...
# Processing Record 15 of Set 6 | mao
# Processing Record 16 of Set 6 | payo
# Processing Record 17 of Set 6 | roswell
# Processing Record 18 of Set 6 | najran
# Processing Record 19 of Set 6 | uzhur
# Processing Record 20 of Set 6 | olafsvik
# Processing Record 21 of Set 6 | ejido
# Processing Record 22 of Set 6 | boralday
# Processing Record 23 of Set 6 | dakar
# Processing Record 24 of Set 6 | fereydunshahr
# Processing Record 25 of Set 6 | say
# Processing Record 26 of Set 6 | beyneu
# Processing Record 27 of Set 6 | beaupre
# Processing Record 28 of Set 6 | garden city
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | batie
# Processing Record 31 of Set 6 | west bay
# Processing Record 32 of Set 6 | kutahya
# Processing Record 33 of Set 6 | kallithea
# Processing Record 34 of Set 6 | tuskegee
# Processing Record 35 of Set 6 | chokurdakh
# Processing Record 36 of Set 6 | blackwater
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | mahibadhoo
# Processing Record 39 of Set 6 | namibe
# Processing Record 40 of Set 6 | dikson
# Processing Record 41 of Set 6 | erdenet
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | mount gambier
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | baillif
# Processing Record 46 of Set 6 | tonekabon
# Processing Record 47 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 6 | lompoc
# Processing Record 49 of Set 6 | tangara
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | ibra
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | naryan-mar
# Processing Record 4 of Set 7 | vangaindrano
# Processing Record 5 of Set 7 | nianzishan
# Processing Record 6 of Set 7 | hobyo
# Processing Record 7 of Set 7 | berlevag
# Processing Record 8 of Set 7 | disna
# Processing Record 9 of Set 7 | vila velha
# Processing Record 10 of Set 7 | kruisfontein
# Processing Record 11 of Set 7 | peniche
# Processing Record 12 of Set 7 | bo
# City not found. Skipping...
# Processing Record 13 of Set 7 | amahai
# Processing Record 14 of Set 7 | gaoua
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | trabzon
# Processing Record 17 of Set 7 | hithadhoo
# Processing Record 18 of Set 7 | koulikoro
# Processing Record 19 of Set 7 | cap malheureux
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | mangrol
# Processing Record 22 of Set 7 | batemans bay
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | hadejia
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | pimentel
# Processing Record 27 of Set 7 | alice springs
# Processing Record 28 of Set 7 | quepos
# Processing Record 29 of Set 7 | zhovkva
# Processing Record 30 of Set 7 | maues
# Processing Record 31 of Set 7 | tagusao
# Processing Record 32 of Set 7 | bafata
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | quatre cocos
# Processing Record 35 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 36 of Set 7 | kungurtug
# Processing Record 37 of Set 7 | caravelas
# Processing Record 38 of Set 7 | gladstone
# Processing Record 39 of Set 7 | bayan
# Processing Record 40 of Set 7 | loum
# Processing Record 41 of Set 7 | suez
# Processing Record 42 of Set 7 | perth
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 46 of Set 7 | mackay
# Processing Record 47 of Set 7 | leshukonskoye
# Processing Record 48 of Set 7 | luena
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | chara
# Processing Record 1 of Set 8 | chimbote
# Processing Record 2 of Set 8 | kanniyakumari
# Processing Record 3 of Set 8 | daru
# Processing Record 4 of Set 8 | whitehorse
# Processing Record 5 of Set 8 | waipawa
# Processing Record 6 of Set 8 | udayagiri
# Processing Record 7 of Set 8 | pisco
# Processing Record 8 of Set 8 | xichang
# Processing Record 9 of Set 8 | kerkini
# Processing Record 10 of Set 8 | catina
# Processing Record 11 of Set 8 | rocha
# Processing Record 12 of Set 8 | saurimo
# Processing Record 13 of Set 8 | dauphin
# Processing Record 14 of Set 8 | henties bay
# Processing Record 15 of Set 8 | puerto madryn
# Processing Record 16 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 8 | mandera
# Processing Record 18 of Set 8 | kyshtovka
# Processing Record 19 of Set 8 | mezhdurechensk
# Processing Record 20 of Set 8 | lisakovsk
# Processing Record 21 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 8 | norden
# Processing Record 23 of Set 8 | saint-louis
# Processing Record 24 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 8 | mangan
# Processing Record 26 of Set 8 | codrington
# Processing Record 27 of Set 8 | buin
# Processing Record 28 of Set 8 | half moon bay
# Processing Record 29 of Set 8 | victoria point
# Processing Record 30 of Set 8 | elizabethton
# Processing Record 31 of Set 8 | mountain home
# Processing Record 32 of Set 8 | pemangkat
# Processing Record 33 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 8 | waddan
# Processing Record 35 of Set 8 | mindif
# Processing Record 36 of Set 8 | svay rieng
# Processing Record 37 of Set 8 | liwale
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | shubarshi
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | chau doc
# Processing Record 42 of Set 8 | kununurra
# Processing Record 43 of Set 8 | mahina
# Processing Record 44 of Set 8 | yumen
# Processing Record 45 of Set 8 | ujiie
# Processing Record 46 of Set 8 | fort nelson
# Processing Record 47 of Set 8 | ramona
# Processing Record 48 of Set 8 | skelleftea
# Processing Record 49 of Set 8 | dedza
# Processing Record 50 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 9 | sorsk
# Processing Record 3 of Set 9 | dolinsk
# Processing Record 4 of Set 9 | san antonio
# Processing Record 5 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 6 of Set 9 | iguape
# Processing Record 7 of Set 9 | andenes
# Processing Record 8 of Set 9 | petropavlovka
# Processing Record 9 of Set 9 | tomatlan
# Processing Record 10 of Set 9 | mecca
# Processing Record 11 of Set 9 | sao tome
# Processing Record 12 of Set 9 | otavi
# Processing Record 13 of Set 9 | waitati
# Processing Record 14 of Set 9 | lazaro cardenas
# Processing Record 15 of Set 9 | kabansk
# Processing Record 16 of Set 9 | champerico
# Processing Record 17 of Set 9 | biskamzha
# Processing Record 18 of Set 9 | sobolevo
# Processing Record 19 of Set 9 | beckley
# Processing Record 20 of Set 9 | kemin
# Processing Record 21 of Set 9 | botou
# Processing Record 22 of Set 9 | scottsbluff
# Processing Record 23 of Set 9 | turayf
# Processing Record 24 of Set 9 | qaqortoq
# Processing Record 25 of Set 9 | yamada
# Processing Record 26 of Set 9 | changtu
# Processing Record 27 of Set 9 | sibolga
# Processing Record 28 of Set 9 | iesolo
# Processing Record 29 of Set 9 | edd
# Processing Record 30 of Set 9 | emilio carranza
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | nelson bay
# Processing Record 35 of Set 9 | horsham
# Processing Record 36 of Set 9 | mehamn
# Processing Record 37 of Set 9 | orange cove
# Processing Record 38 of Set 9 | omsukchan
# Processing Record 39 of Set 9 | guozhen
# Processing Record 40 of Set 9 | lerwick
# Processing Record 41 of Set 9 | kendari
# Processing Record 42 of Set 9 | primore
# City not found. Skipping...
# Processing Record 43 of Set 9 | nouakchott
# Processing Record 44 of Set 9 | saint-paul
# Processing Record 45 of Set 9 | raudeberg
# Processing Record 46 of Set 9 | south valley
# Processing Record 47 of Set 9 | zyryanovsk
# Processing Record 48 of Set 9 | annamalainagar
# Processing Record 49 of Set 9 | muravlenko
# Processing Record 50 of Set 9 | biu
# Processing Record 1 of Set 10 | magistralnyy
# Processing Record 2 of Set 10 | yurimaguas
# Processing Record 3 of Set 10 | weligama
# Processing Record 4 of Set 10 | zhaotong
# Processing Record 5 of Set 10 | prince rupert
# Processing Record 6 of Set 10 | tuatapere
# Processing Record 7 of Set 10 | fuxin
# Processing Record 8 of Set 10 | mezhdurechenskiy
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | megion
# Processing Record 11 of Set 10 | pangnirtung
# Processing Record 12 of Set 10 | puerto escondido
# Processing Record 13 of Set 10 | atar
# Processing Record 14 of Set 10 | chiredzi
# Processing Record 15 of Set 10 | marzuq
# Processing Record 16 of Set 10 | maceio
# Processing Record 17 of Set 10 | that phanom
# Processing Record 18 of Set 10 | opuwo
# Processing Record 19 of Set 10 | bubaque
# Processing Record 20 of Set 10 | nurota
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | santarem
# Processing Record 23 of Set 10 | togur
# Processing Record 24 of Set 10 | batangafo
# Processing Record 25 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 26 of Set 10 | plainview
# Processing Record 27 of Set 10 | bilma
# Processing Record 28 of Set 10 | molchanovo
# Processing Record 29 of Set 10 | aksu
# Processing Record 30 of Set 10 | machakos
# Processing Record 31 of Set 10 | anklam
# Processing Record 32 of Set 10 | pedernales
# Processing Record 33 of Set 10 | eirunepe
# Processing Record 34 of Set 10 | kismayo
# Processing Record 35 of Set 10 | burns lake
# Processing Record 36 of Set 10 | villarrica
# Processing Record 37 of Set 10 | ambilobe
# Processing Record 38 of Set 10 | gondar
# Processing Record 39 of Set 10 | dunedin
# Processing Record 40 of Set 10 | bonfim
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | pervomayskiy
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | mount isa
# Processing Record 45 of Set 10 | santa rosa
# Processing Record 46 of Set 10 | pontianak
# Processing Record 47 of Set 10 | novo aripuana
# Processing Record 48 of Set 10 | hirado
# Processing Record 49 of Set 10 | itarema
# Processing Record 50 of Set 10 | kitaibaraki
# Processing Record 1 of Set 11 | phonhong
# Processing Record 2 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 11 | manglisi
# Processing Record 4 of Set 11 | varnamo
# Processing Record 5 of Set 11 | nizwa
# Processing Record 6 of Set 11 | dasoguz
# Processing Record 7 of Set 11 | miraflores
# Processing Record 8 of Set 11 | swan hill
# Processing Record 9 of Set 11 | tucuman
# Processing Record 10 of Set 11 | fairbanks
# Processing Record 11 of Set 11 | wagar
# Processing Record 12 of Set 11 | barre
# Processing Record 13 of Set 11 | alekseyevsk
# Processing Record 14 of Set 11 | gat
# Processing Record 15 of Set 11 | kalmunai
# Processing Record 16 of Set 11 | valparaiso
# Processing Record 17 of Set 11 | port augusta
# Processing Record 18 of Set 11 | ciudad bolivar
# Processing Record 19 of Set 11 | yarmouth
# Processing Record 20 of Set 11 | westerland
# Processing Record 21 of Set 11 | araouane
# Processing Record 22 of Set 11 | yarada
# Processing Record 23 of Set 11 | richards bay
# Processing Record 24 of Set 11 | foumbot
# Processing Record 25 of Set 11 | gigmoto
# Processing Record 26 of Set 11 | angol
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | moline
# Processing Record 29 of Set 11 | benghazi
# Processing Record 30 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 11 | guarapari
# Processing Record 32 of Set 11 | khandyga
# Processing Record 33 of Set 11 | noumea
# Processing Record 34 of Set 11 | yenagoa
# Processing Record 35 of Set 11 | ha tinh
# Processing Record 36 of Set 11 | marion
# Processing Record 37 of Set 11 | san diego
# Processing Record 38 of Set 11 | shimoda
# Processing Record 39 of Set 11 | khudumelapye
# Processing Record 40 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 11 | warrington
# Processing Record 42 of Set 11 | bati
# Processing Record 43 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 11 | shelburne
# Processing Record 45 of Set 11 | krasnoselkup
# Processing Record 46 of Set 11 | aksarka
# Processing Record 47 of Set 11 | vilhena
# Processing Record 48 of Set 11 | wawa
# Processing Record 49 of Set 11 | inhambane
# Processing Record 50 of Set 11 | mweka
# Processing Record 1 of Set 12 | kaeo
# Processing Record 2 of Set 12 | carmelo
# Processing Record 3 of Set 12 | seabra
# Processing Record 4 of Set 12 | pathein
# Processing Record 5 of Set 12 | labrea
# Processing Record 6 of Set 12 | bialystok
# Processing Record 7 of Set 12 | guerrero negro
# Processing Record 8 of Set 12 | la asuncion
# Processing Record 9 of Set 12 | chipinge
# Processing Record 10 of Set 12 | hornepayne
# Processing Record 11 of Set 12 | roald
# Processing Record 12 of Set 12 | semey
# Processing Record 13 of Set 12 | bandarbeyla
# Processing Record 14 of Set 12 | seidu
# Processing Record 15 of Set 12 | nikolayevsk-na-amure
# Processing Record 16 of Set 12 | akhaldaba
# Processing Record 17 of Set 12 | talnakh
# Processing Record 18 of Set 12 | provost
# Processing Record 19 of Set 12 | general roca
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | wuan
# Processing Record 22 of Set 12 | chumikan
# Processing Record 23 of Set 12 | presidente epitacio
# Processing Record 24 of Set 12 | voskresenskoye
# Processing Record 25 of Set 12 | bereda
# Processing Record 26 of Set 12 | preston
# Processing Record 27 of Set 12 | digby
# Processing Record 28 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 29 of Set 12 | pinar del rio
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | villa carlos paz
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | turochak
# Processing Record 35 of Set 12 | vanimo
# Processing Record 36 of Set 12 | surt
# Processing Record 37 of Set 12 | dhidhdhoo
# Processing Record 38 of Set 12 | rio grande
# Processing Record 39 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 12 | shimorskoye
# Processing Record 41 of Set 12 | show low
# Processing Record 42 of Set 12 | rio pardo
# Processing Record 43 of Set 12 | xuanhua
# Processing Record 44 of Set 12 | tremedal
# Processing Record 45 of Set 12 | high rock
# Processing Record 46 of Set 12 | mackenzie
# Processing Record 47 of Set 12 | san carlos de bariloche
# Processing Record 48 of Set 12 | portsmouth
# Processing Record 49 of Set 12 | catamarca
# Processing Record 50 of Set 12 | galle
# Processing Record 1 of Set 13 | bullhead city
# Processing Record 2 of Set 13 | coihaique
# Processing Record 3 of Set 13 | sayat
# Processing Record 4 of Set 13 | dandong
# Processing Record 5 of Set 13 | timizart
# Processing Record 6 of Set 13 | yuryuzan
# Processing Record 7 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | atkinson
# Processing Record 9 of Set 13 | singaparna
# Processing Record 10 of Set 13 | chicama
# Processing Record 11 of Set 13 | boras
# Processing Record 12 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 13 | hami
# Processing Record 14 of Set 13 | abrau-dyurso
# Processing Record 15 of Set 13 | metro
# Processing Record 16 of Set 13 | kasungu
# Processing Record 17 of Set 13 | the pas
# Processing Record 18 of Set 13 | polunochnoye
# Processing Record 19 of Set 13 | adre
# Processing Record 20 of Set 13 | jiangyou
# Processing Record 21 of Set 13 | maniitsoq
# Processing Record 22 of Set 13 | sarkand
# Processing Record 23 of Set 13 | diamantino
# Processing Record 24 of Set 13 | lasa
# Processing Record 25 of Set 13 | poso
# Processing Record 26 of Set 13 | vostok
# Processing Record 27 of Set 13 | robertsganj
# Processing Record 28 of Set 13 | sinnamary
# Processing Record 29 of Set 13 | sola
# Processing Record 30 of Set 13 | tenenkou
# Processing Record 31 of Set 13 | te anau
# Processing Record 32 of Set 13 | visnes
# Processing Record 33 of Set 13 | flagstaff
# Processing Record 34 of Set 13 | shushtar
# Processing Record 35 of Set 13 | kampot
# Processing Record 36 of Set 13 | guisa
# Processing Record 37 of Set 13 | victor harbor
# Processing Record 38 of Set 13 | swabi
# Processing Record 39 of Set 13 | bilibino
# Processing Record 40 of Set 13 | ucluelet
# Processing Record 41 of Set 13 | haines junction
# Processing Record 42 of Set 13 | kholodnyy
# Processing Record 43 of Set 13 | sicamous
# Processing Record 44 of Set 13 | lulea
# Processing Record 45 of Set 13 | axim
# Processing Record 46 of Set 13 | la palma
# Processing Record 47 of Set 13 | port blair
# Processing Record 48 of Set 13 | shymkent
# Processing Record 49 of Set 13 | northam
# Processing Record 50 of Set 13 | iskateley
# Processing Record 1 of Set 14 | rafraf
# Processing Record 2 of Set 14 | labuan
# Processing Record 3 of Set 14 | la ronge
# Processing Record 4 of Set 14 | nokaneng
# Processing Record 5 of Set 14 | shubarkuduk
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | smithers
# Processing Record 8 of Set 14 | burnie
# Processing Record 9 of Set 14 | sisophon
# Processing Record 10 of Set 14 | hervey bay
# Processing Record 11 of Set 14 | ambovombe
# Processing Record 12 of Set 14 | kambia
# Processing Record 13 of Set 14 | ribeirao branco
# Processing Record 14 of Set 14 | port moresby
# Processing Record 15 of Set 14 | zalantun
# Processing Record 16 of Set 14 | esso
# Processing Record 17 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 14 | margate
# Processing Record 21 of Set 14 | bonthe
# Processing Record 22 of Set 14 | clermont
# Processing Record 23 of Set 14 | gizo
# Processing Record 24 of Set 14 | dzilam gonzalez
# Processing Record 25 of Set 14 | okha
# Processing Record 26 of Set 14 | mosquera
# Processing Record 27 of Set 14 | karaidel
# Processing Record 28 of Set 14 | moose factory
# Processing Record 29 of Set 14 | thinadhoo
# Processing Record 30 of Set 14 | fernley
# Processing Record 31 of Set 14 | marystown
# Processing Record 32 of Set 14 | kinablangan
# Processing Record 33 of Set 14 | sakakah
# Processing Record 34 of Set 14 | kashi
# Processing Record 35 of Set 14 | kijang
# Processing Record 36 of Set 14 | ewo
# Processing Record 37 of Set 14 | poplar bluff
# Processing Record 38 of Set 14 | mandalgovi
# Processing Record 39 of Set 14 | antofagasta
# Processing Record 40 of Set 14 | areka
# Processing Record 41 of Set 14 | rastatt
# Processing Record 42 of Set 14 | voh
# Processing Record 43 of Set 14 | sioux lookout
# Processing Record 44 of Set 14 | sayyan
# Processing Record 45 of Set 14 | aklavik
# Processing Record 46 of Set 14 | punta cardon
# Processing Record 47 of Set 14 | benesov
# Processing Record 48 of Set 14 | uvinza
# Processing Record 49 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 14 | iroquois falls
# Processing Record 1 of Set 15 | morgan city
# Processing Record 2 of Set 15 | da nang
# Processing Record 3 of Set 15 | tarnos
# Processing Record 4 of Set 15 | bagaces
# Processing Record 5 of Set 15 | constitucion
# Processing Record 6 of Set 15 | portland
# Processing Record 7 of Set 15 | kiunga
# Processing Record 8 of Set 15 | tulum
# Processing Record 9 of Set 15 | yarim
# Processing Record 10 of Set 15 | krasnoarmeysk
# Processing Record 11 of Set 15 | vegueta
# Processing Record 12 of Set 15 | mogadishu
# Processing Record 13 of Set 15 | along
# Processing Record 14 of Set 15 | novosokolniki
# Processing Record 15 of Set 15 | erechim
# Processing Record 16 of Set 15 | sidi ali
# Processing Record 17 of Set 15 | nizhnyaya tavda
# Processing Record 18 of Set 15 | banyo
# Processing Record 19 of Set 15 | samba
# Processing Record 20 of Set 15 | brainerd
# Processing Record 21 of Set 15 | dali
# Processing Record 22 of Set 15 | rovinj
# Processing Record 23 of Set 15 | cairns
# Processing Record 24 of Set 15 | simpang
# Processing Record 25 of Set 15 | san jeronimo
# Processing Record 26 of Set 15 | dubai
# Processing Record 27 of Set 15 | shakawe
# Processing Record 28 of Set 15 | elektrenai
# Processing Record 29 of Set 15 | belaya gora
# Processing Record 30 of Set 15 | danilovka
# Processing Record 31 of Set 15 | tahe
# Processing Record 32 of Set 15 | tommot
# Processing Record 33 of Set 15 | ludvika
# Processing Record 34 of Set 15 | guelengdeng
# City not found. Skipping...
# Processing Record 35 of Set 15 | lensk
# Processing Record 36 of Set 15 | azangaro
# Processing Record 37 of Set 15 | gonbad-e qabus
# Processing Record 38 of Set 15 | port keats
# Processing Record 39 of Set 15 | bambanglipuro
# Processing Record 40 of Set 15 | lengshuitan
# Processing Record 41 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 42 of Set 15 | springbok
# Processing Record 43 of Set 15 | corrente
# Processing Record 44 of Set 15 | abu dhabi
# Processing Record 45 of Set 15 | gijon
# Processing Record 46 of Set 15 | afsin
# Processing Record 47 of Set 15 | roseburg
# Processing Record 48 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 15 | thabazimbi
# Processing Record 50 of Set 15 | yangshe
# Processing Record 1 of Set 16 | boyolangu
# Processing Record 2 of Set 16 | anqing
# Processing Record 3 of Set 16 | yerbogachen
# Processing Record 4 of Set 16 | jaca
# Processing Record 5 of Set 16 | upata
# Processing Record 6 of Set 16 | lakes entrance
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Riohacha  11.5444  -72.9072     89.46        59          27
# 1               Barrow  71.2906 -156.7887     27.30        94         100
# 2             Pochutla  15.7432  -96.4661     74.82        88          97
# 3              Ahipara -35.1667  173.1667     60.60        97          99
# 4             Khatanga  71.9667  102.5000     13.10        92         100
# 5          East London -33.0153   27.9116     66.04        64          65
# 6              Ushuaia -54.8000  -68.3000     44.22        87          90
# 7            Busselton -33.6500  115.3333     55.09        84          11
# 8                 Hovd  48.0056   91.6419     37.89        51          97
# 9  Mihail Kogalniceanu  44.3667   28.4500     55.67        71           0
#
#    Wind Speed Country Current Description
# 0       16.69      CO    scattered clouds
# 1       15.84      US     overcast clouds
# 2        2.30      MX     overcast clouds
# 3        1.72      NZ          light rain
# 4       17.18      RU     overcast clouds
# 5       30.09      ZA       broken clouds
# 6       31.07      AR       moderate rain
# 7        7.36      AU          few clouds
# 8        5.26      MN     overcast clouds
# 9        5.75      RO          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Riohacha      CO  11.5444  -72.9072     89.46        59
# 1               Barrow      US  71.2906 -156.7887     27.30        94
# 2             Pochutla      MX  15.7432  -96.4661     74.82        88
# 3              Ahipara      NZ -35.1667  173.1667     60.60        97
# 4             Khatanga      RU  71.9667  102.5000     13.10        92
# 5          East London      ZA -33.0153   27.9116     66.04        64
# 6              Ushuaia      AR -54.8000  -68.3000     44.22        87
# 7            Busselton      AU -33.6500  115.3333     55.09        84
# 8                 Hovd      MN  48.0056   91.6419     37.89        51
# 9  Mihail Kogalniceanu      RO  44.3667   28.4500     55.67        71
#
#    Cloudiness  Wind Speed Current Description
# 0          27       16.69    scattered clouds
# 1         100       15.84     overcast clouds
# 2          97        2.30     overcast clouds
# 3          99        1.72          light rain
# 4         100       17.18     overcast clouds
# 5          65       30.09       broken clouds
# 6          90       31.07       moderate rain
# 7          11        7.36          few clouds
# 8          97        5.26     overcast clouds
# 9           0        5.75          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
